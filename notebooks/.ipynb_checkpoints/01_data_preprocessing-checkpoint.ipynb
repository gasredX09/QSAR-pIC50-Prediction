# %%
import sys
sys.path.append("../src")

from dataset_builder import DatasetBuilder

builder = DatasetBuilder("CHEMBL220")   # Acetylcholinesterase
cleanDF = builder.runPipeline("../data/processed/clean_bioactivity.csv")

# cleanDF.head()
# Out:
# Requesting data from ChEMBL...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       4 from dataset_builder import DatasetBuilder
#       6 builder = DatasetBuilder("CHEMBL220")   # Acetylcholinesterase
# ----> 7 builder.fetchFromChEMBL()
#
# File ~/QSAR-pIC50-Prediction/notebooks/../src/dataset_builder.py:42, in DatasetBuilder.fetchFromChEMBL(self)
#      39 resultGen = activity.filter(target_chembl_id=self.targetID).only(fields)
#      41 # Convert into list explicitly (forces pagination cleanly)
# ---> 42 results = list(resultGen)
#      43 print(f"Downloaded {len(results)} activity records.")
#      45 self.rawDF = pd.DataFrame(results)
#
# File ~/miniconda3/envs/mlproj/lib/python3.10/site-packages/chembl_webresource_client/query_set.py:127, in QuerySet.__next__(self)
#     126 def __next__(self):
# --> 127     return self.next()
#
# ...
