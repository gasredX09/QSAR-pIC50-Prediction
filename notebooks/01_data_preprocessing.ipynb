# %%
import sys
sys.path.append("../src")

from dataset_builder import DatasetBuilder
import pandas as pd

# %%
builder = DatasetBuilder("acetylcholinesterase", limit=500)

# %%
output_path = "../data/processed/acetylcholinesterase_bioactivity.csv"
df = builder.runPipeline(output_path)
df.head()
# Out:
# Selected Target ID: CHEMBL220
# Fetching activity data...
# Fetched: 500 rows
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1       CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2       CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3       CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4       CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
#
#    standard_value_nM     pIC50 bioactivity_class
# 0              750.0  6.124939            active
# 1              100.0  7.000000            active
# 2            50000.0  4.301030          inactive
# 3              300.0  6.522879            active
# 4              800.0  6.096910            active
