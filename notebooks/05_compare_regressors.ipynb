# %%
import sys
sys.path.append("../src")

from model_comparator import ModelComparator

mc = ModelComparator("../data/descriptors/final_dataset.csv")
results = mc.run()

results
# Out:
# Loaded 415 rows, 1753 columns.
# After cleaning: (301, 1247)
# After filtering: (301, 1190) features
#
# Running model comparison...
#
# Training RandomForest...
# Training ExtraTrees...
# Training GradientBoosting...
# Training DecisionTree...
#
# Saved comparison table to ../results/comparison/regressor_comparison.csv
# Saved RMSE plot to ../results/comparison/rmse_plot.png
#               Model        R2      RMSE       MAE
# 1        ExtraTrees  0.646490  0.841772  0.608060
# 2  GradientBoosting  0.533859  0.966612  0.745656
# 0      RandomForest  0.499911  1.001192  0.750367
# 3      DecisionTree -0.003456  1.418218  0.936201
