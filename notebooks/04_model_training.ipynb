# %%
import sys
sys.path.append("../src")

from activity_model import ActivityModel

am = ActivityModel()

# load
df = am.loadDataset("../data/descriptors/final_dataset.csv")

# prepare features
X, y = am.prepareXY(df)

# train + evaluate
am.train(X, y)

# save model
am.saveModel("../model/final_model.pkl")
# Out:
# Model Performance:
# R²:   0.4989
# RMSE: 1.0022
# MAE:  0.7544
# Saved model to ../model/final_model.pkl
