# %%
import sys
sys.path.append("../src")

from eda_engine import EDAEngine

eda = EDAEngine("../data/processed/acetylcholinesterase_bioactivity.csv")
df = eda.run()

df.head()
# Out:
# Loaded 415 rows from: ../data/processed/acetylcholinesterase_bioactivity.csv
# Computed Lipinski descriptors.
# Saved summary statistics.
# Saved: MW_boxplot.png
# Saved: MW_vs_pIC50.png
# Saved: LogP_boxplot.png
# Saved: LogP_vs_pIC50.png
# Saved: HBD_boxplot.png
# Saved: HBD_vs_pIC50.png
# Saved: HBA_boxplot.png
# Saved: HBA_vs_pIC50.png
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1       CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2       CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3       CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4       CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
#
#    standard_value_nM     pIC50 bioactivity_class       MW    LogP  HBD  HBA
# 0              750.0  6.124939            active  312.325  2.8032    0    6
# ...
